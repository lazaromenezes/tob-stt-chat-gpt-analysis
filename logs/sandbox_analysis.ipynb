# %%
import pandas as pd

tob = pd.read_csv('./tob_v1_x_v2.csv')

tob.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  user                    question question_class  \
# 0             0           0   100                          hi          Greet
# 1             1           1   100                      Simone      Statement
# 2             2           2   100                 I am Simone      Statement
# 3             3           3   100    what is software testing     whQuestion
# 4             4           4   100  what is structural testing     whQuestion
#
#                                            answer_v1  \
# 0                                Hello, how are you?
# 1  Sorry, I still can't answer that.. Could you a...
# 2  Sorry, I still can't answer that.. Could you a...
# 3  Software testing is an activity of software en...
# 4  Structural testing (or White-Box testing) is a...
#
#                                            answer_v2   v1_x_v2
# 0                                                 Hi  0.618338
# ...

# %%
tob[tob['user'] == 110]
# Out:
#      Unnamed: 0.1  Unnamed: 0  user                     question  \
# 203           203         203   110                           Hi
# 204           204         204   110                    Good, you
# 205           205         205   110                          How
# 206           206         206   110                          Yes
# 207           207         207   110                           No
# 208           208         208   110                        Fault
# 209           209         209   110              What is a fault
# 210           210         210   110             What is an error
# 211           211         211   110              What is failure
# 212           212         212   110           What is a test set
# 213           213         213   110                Test coverage
# 214           214         214   110        What is test coverage
# 215           215         215   110          What is a test case
# ...

# %%
tob[tob['v1_x_v2'] >= 0.75]
# Out:
#       Unnamed: 0.1  Unnamed: 0  user                          question  \
# 3                3           3   100          what is software testing
# 4                4           4   100        what is structural testing
# 6                6           6   100            what is system testing
# 7                7           7   100              what is unit testing
# 8                8           8   100       what is integration testing
# ...            ...         ...   ...                               ...
# 2971          2971        2971    98       comment on software testing
# 2972          2972        2972    98  lets talk about software testing
# 2976          2976        2976    98  Lets talk about software testing
# 2979          2979        2979    98  what is state transitioning test
# 2982          2982        2982    98          what is state transition
#
#      question_class                                          answer_v1  \
# ...
