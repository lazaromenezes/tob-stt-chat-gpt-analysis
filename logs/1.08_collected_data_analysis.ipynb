# %%
import pandas as pd

tob = pd.read_csv('tob_gpt_similarity.csv', index_col='index')

# %%
tob = tob.drop('Unnamed: 0', axis=1)

# %%
tob[tob['v1_x_v2'] >= 0.85].sort_values('v1_x_v2')
# Out:
#        user                                           question question_class  \
# index
# 1192    159  What is the difference between structural test...     whQuestion
# 727     145     what is the difference between error and fault        Clarify
# 199      10                   How to apply functional testing?     whQuestion
# 202      10             How to apply equivalence partitioning?     whQuestion
# 1352    166     give me an example of equivalence partitioning      Statement
# ...     ...                                                ...            ...
# 218     110                          What is white box testing     whQuestion
# 1811     22                           What is an input domain?     whQuestion
# 568     130                          What is white-box testing     whQuestion
# 187     109                      What is the white-box testing     whQuestion
# 167     108                                 what is 52 testing     whQuestion
#
# ...

# %%
tob[tob['question_cluster'] >= 138].sort_values('v1_x_v2')
# Out:
#       Unnamed: 0  index  user                           question  \
# 1654        1654   2702    93  what is software testing activity
# 1275        1275   1834    23               and what is a fault?
# 1707        1707   2844    96     How apply limit value analysis
# 1349        1349   2072    34                    who is testing?
# 1333        1333   2055    34                  so, what is test?
# ...          ...    ...   ...                                ...
# 464          464    605   134                    what is testing
# 161          161    218   110          What is white box testing
# 468          468    614   134          what is black-box testing
# 495          495    663   140          what is white-box testing
# 512          512    685   142               what is input domain
#
#      question_class  question_cluster  \
# 1654     whQuestion               239
# 1275     whQuestion               234
# 1707        Clarify               140
# ...

# %%
tob[tob['v1_x_v2'] < 0]
# Out:
#        user                                           question question_class  \
# index
# 44      101                                      Alpha testing      Statement
# 63      103                           waht is software testing      Statement
# 85      104            I nedd to know what is software testing      Statement
# 86      104            I need to know what is software testing      Statement
# 134     106  Which problems are associated with software te...         Reject
# ...     ...                                                ...            ...
# 2942     96                                      example error      Statement
# 2955     96  can you give me an example of limit value anal...     ynQuestion
# 2957     96      what is the boundarie value analysis criteria     whQuestion
# 2980     98                what is state transitioning testing     whQuestion
# 2985     98                              what is graph testing     whQuestion
#
# ...

# %%
# Out:
# (1822, 10)
