# %%
import openai
import pandas as pd

# %%
questions = pd.read_csv("./tob_v1_classified.csv", index_col='index')

# %%
questions.head()
# Out:
#        user                    question  \
# index
# 0       100                          hi
# 1       100                      Simone
# 2       100                 I am Simone
# 3       100    what is software testing
# 4       100  what is structural testing
#
#                                                   answer question_class
# index
# 0                                    Hello, how are you?          Greet
# 1      Sorry, I still can't answer that.. Could you a...      Statement
# 2      Sorry, I still can't answer that.. Could you a...      Statement
# 3      Software testing is an activity of software en...     whQuestion
# 4      Structural testing (or White-Box testing) is a...     whQuestion

# %%
wh_questions = questions[questions["question_class"] == "whQuestion"]

wh_questions
# Out:
#       Unnamed: 0  user                                           question  \
# 3              3   100                           what is software testing
# 4              4   100                         what is structural testing
# 5              5   100                       what is a software technique
# 6              6   100                             what is system testing
# 7              7   100                               what is unit testing
# ...          ...   ...                                                ...
# 2982        2982    98                           what is state transition
# 2983        2983    98                   what is state transition testing
# 2984        2984    98  what is the definition of state transition tes...
# 2985        2985    98                              what is graph testing
# 2986        2986    98                       what is graph matrix testing
#
#                                                  answer question_class
# 3     Software testing is an activity of software en...     whQuestion
# 4     Structural testing (or White-Box testing) is a...     whQuestion
# 5     Sorry, I still can't answer that.. Could you a...     whQuestion
# 6     System testing is a level of software testing ...     whQuestion
# 7     Unit testing verifies the functioning in isola...     whQuestion
# ...                                                 ...            ...
# 2982  It is a criteria within functional testing, bu...     whQuestion
# 2983  It is a criteria within functional testing, bu...     whQuestion
# 2984  It is a criteria within functional testing, bu...     whQuestion
# 2985  Software testing is an activity of software en...     whQuestion
# 2986  It is a criteria within functional testing, bu...     whQuestion
#
# [1395 rows x 5 columns]

# %%
user_question = wh_questions.sample()["question"].item()
user_question
# Out:
# 'How do the faults in a software appear'

# %%
# https://platform.openai.com/docs/libraries/python-library
openai.api_key = "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"
gpt_response = openai.ChatCompletion.create(model="gpt-3.5-turbo", messages=[{"role": "user", "content": user_question}])

gpt_response
# Out:
# <OpenAIObject chat.completion id=chatcmpl-7rZmo9vuLLDIJpmN68N5zzD2X7EhS at 0x7f23d9cab230> JSON: {
#   "id": "chatcmpl-7rZmo9vuLLDIJpmN68N5zzD2X7EhS",
#   "object": "chat.completion",
#   "created": 1693003302,
#   "model": "gpt-3.5-turbo-0613",
#   "choices": [
#     {
#       "index": 0,
#       "message": {
#         "role": "assistant",
#         "content": "Faults in software can appear in various ways, and they may occur due to a variety of reasons. Here are some common ways in which faults can appear in software:\n\n1. Programming errors: These faults result from mistakes made by programmers during the software development process. They can include syntax errors, logical errors, or incorrect implementation of algorithms or business rules.\n\n2. Incomplete or incorrect requirements: If the software requirements are ambiguous, inconsistent, or incomplete, it can lead to faults in the final software. Often, inadequate communication or understanding between the development team and stakeholders can contribute to this.\n\n3. Design flaws: Faults can arise from poor system architecture, incorrect data structures, or improper program flow. Insufficient attention to design principles or failure to foresee certain scenarios can lead to these flaws.\n\n4. Integration or compatibility issues: In complex software systems, faults can occur when different components or modules do not work together correctly. This can result from incompatible interfaces, mismatches in data formats, or interoperability problems.\n\n5. External factors: Faults can also come from external sources like hardware failures, network issues, or external software dependencies. For example, a software component may work fine on one computer but fail on another due to a compatibility issue with a specific hardware configuration.\n\n6. Time-related issues: Faults may arise over time due to wear and tear, resource exhaustion, or accumulation of temporary data. These faults can be symptoms of underlying problems related to memory management, resource allocation, or data handling.\n\n7. Security vulnerabilities: Faults in software can lead to security vulnerabilities, such as buffer overflows, injection attacks, or insecure authentication mechanisms. These vulnerabilities can be exploited by malicious actors to gain unauthorized access or disrupt system functionality.\n\nIt is worth noting that faults may not always manifest as visible errors or crashes. They can also manifest as performance issues, incorrect outputs, unexpected behaviors, or even subtle issues that impact the user experience. Skilled software testing, rigorous code reviews, and adherence to best practices during the development lifecycle can help minimize such faults."
#       },
#       "finish_reason": "stop"
#     }
#   ],
#   "usage": {
#     "prompt_tokens": 15,
#     "completion_tokens": 412,
#     "total_tokens": 427
#   }
# }

# %%
gpt_response.choices[0].message.content
# Out:
# 'Faults in software can appear in various ways, and they may occur due to a variety of reasons. Here are some common ways in which faults can appear in software:\n\n1. Programming errors: These faults result from mistakes made by programmers during the software development process. They can include syntax errors, logical errors, or incorrect implementation of algorithms or business rules.\n\n2. Incomplete or incorrect requirements: If the software requirements are ambiguous, inconsistent, or incomplete, it can lead to faults in the final software. Often, inadequate communication or understanding between the development team and stakeholders can contribute to this.\n\n3. Design flaws: Faults can arise from poor system architecture, incorrect data structures, or improper program flow. Insufficient attention to design principles or failure to foresee certain scenarios can lead to these flaws.\n\n4. Integration or compatibility issues: In complex software systems, faults can occur when different components or modules do not work together correctly. This can result from incompatible interfaces, mismatches in data formats, or interoperability problems.\n\n5. External factors: Faults can also come from external sources like hardware failures, network issues, or external software dependencies. For example, a software component may work fine on one computer but fail on another due to a compatibility issue with a specific hardware configuration.\n\n6. Time-related issues: Faults may arise over time due to wear and tear, resource exhaustion, or accumulation of temporary data. These faults can be symptoms of underlying problems related to memory management, resource allocation, or data handling.\n\n7. Security vulnerabilities: Faults in software can lead to security vulnerabilities, such as buffer overflows, injection attacks, or insecure authentication mechanisms. These vulnerabilities can be exploited by malicious actors to gain unauthorized access or disrupt system functionality.\n\nIt is worth noting that faults may not always manifest as visible errors or crashes. They can also manifest as performance issues, incorrect outputs, unexpected behaviors, or even subtle issues that impact the user experience. Skilled software testing, rigorous code reviews, and adherence to best practices during the development lifecycle can help minimize such faults.'

# %%
def ask_gpt(model, prompt):
    sleep(12) # Open AI restricts requests to 5 per second
    gpt_response = openai.ChatCompletion.create(model=model, messages=[{"role": "user", "content": prompt}])   
    return gpt_response.choices[0].message.content

# %%
#wh_questions["gpt-3.5-turbo"] = wh_questions["question"].apply(lambda q: ask_gpt("gpt-3.5-turbo", q))

sample_questions = wh_questions.sample(10)
sample_questions
# Out:
#       Unnamed: 0  user                                 question  \
# 1651        1651   206                                     What
# 2094        2094    38      What are the partitioning criteria?
# 2964        2964    96                           what is a test
# 2458        2458    74                  and what is a test case
# 1111        1111   154  What is a software inconsistency defect
# 1558        1558   193                       what is is a fault
# 1106        1106   154         What is a feature omission error
# 1229        1229   160       what is a equivalence partitioning
# 369          369   121             what is successful test case
# 620          620   134               what is functional testing
#
#                                                  answer question_class
# 1651  Sorry, I still can't answer that.. Could you a...     whQuestion
# 2094                       Try searching the Wikipedia.     whQuestion
# 2964  A test, in software testing, is the act of per...     whQuestion
# 2458                   I don't know how to respond this     whQuestion
# 1111  A software defect or bug is a condition in a s...     whQuestion
# 1558  Fault is an incorrect step, process, or data d...     whQuestion
# 1106  An error is a state of execution of the progra...     whQuestion
# 1229  Equivalence partitioning is a functional testi...     whQuestion
# 369   A test case is composed by the test input, the...     whQuestion
# 620   Functional testing (or Black Box Testing) is a...     whQuestion

# %%
sample_questions["gpt-4"] = sample_questions["question"].apply(lambda q: ask_gpt("gpt-4", q))

# %%
sample_questions
# Out:
#       Unnamed: 0  user                                 question  \
# 1651        1651   206                                     What
# 2094        2094    38      What are the partitioning criteria?
# 2964        2964    96                           what is a test
# 2458        2458    74                  and what is a test case
# 1111        1111   154  What is a software inconsistency defect
# 1558        1558   193                       what is is a fault
# 1106        1106   154         What is a feature omission error
# 1229        1229   160       what is a equivalence partitioning
# 369          369   121             what is successful test case
# 620          620   134               what is functional testing
#
#                                                  answer question_class  \
# 1651  Sorry, I still can't answer that.. Could you a...     whQuestion
# 2094                       Try searching the Wikipedia.     whQuestion
# 2964  A test, in software testing, is the act of per...     whQuestion
# 2458                   I don't know how to respond this     whQuestion
# 1111  A software defect or bug is a condition in a s...     whQuestion
# 1558  Fault is an incorrect step, process, or data d...     whQuestion
# 1106  An error is a state of execution of the progra...     whQuestion
# 1229  Equivalence partitioning is a functional testi...     whQuestion
# 369   A test case is composed by the test input, the...     whQuestion
# 620   Functional testing (or Black Box Testing) is a...     whQuestion
#
#                                           gpt-3.5-turbo  \
# 1651                                  is your question?
# 2094  Partitioning criteria are used to determine ho...
# 2964  A test is a method or process used to assess s...
# 2458  A test case is a specific set of conditions an...
# 1111  A software inconsistency defect refers to a ty...
# 1558  A fault is a break or fracture along which roc...
# 1106  A feature omission error refers to a mistake o...
# 1229  Equivalence partitioning is a software testing...
# 369   A successful test case is one that produces th...
# 620   Functional testing is a type of software testi...
#
#                                                   gpt-4
# 1651  Hello! It seems you've not completed your ques...
# 2094  Partitioning criteria are the conditions or ru...
# 2964  A test is an examination or assessment intende...
# 2458  A test case is a set of conditions or variable...
# 1111  A software inconsistency defect, also known as...
# 1558  In geology, a fault is a fracture or zone of f...
# 1106  A feature omission error refers to a mistake m...
# 1229  Equivalence Partitioning is a software testing...
# 369   A successful test case is one that has been ex...
# 620   Functional testing is a type of software testi...

# %%
sample_questions.to_csv("openai-sample.csv")
