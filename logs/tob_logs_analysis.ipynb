# %%
# https://www.nltk.org/book/ch06.html

import nltk
from nltk.corpus import nps_chat

# %%
# download nltk data

nltk.download('punkt')
nltk.download('nps_chat')
# Out:
# [nltk_data] Downloading package punkt to /home/jovyan/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package nps_chat to /home/jovyan/nltk_data...
# [nltk_data]   Unzipping corpora/nps_chat.zip.
# True

# %%
# define a feature extractor (post words) 
def dialogue_act_features(post):
    features = {}
    
    for word in nltk.word_tokenize(post):
        features[f'contains({word})'] = True

    return features

# %%
# import nps_chat posts and create a dev-test dataset

nps_posts = nps_chat.xml_posts()[:10000]

feature_dataset = [(dialogue_act_features(post.text), post.get('class')) for post in nps_posts]

# 80% train, 20% test
test_size = int(len(feature_dataset) * 0.2)

train_data, test_data = feature_dataset[test_size:], feature_dataset[:test_size]

# %%
# create a classifier and test it

classifier = nltk.NaiveBayesClassifier.train(train_data)

print(nltk.classify.accuracy(classifier, test_data))
# Out:
# 0.6445

# %%
import pandas as pd

# %%
# import tob-stt v1 logs
v1logs = pd.read_csv("./tob_v1_dataset")

# %%
# classifier function for tob logs

def classify_question(question):
    return classifier.classify(dialogue_act_features(question))

# %%
# classify questions

classified_logs = v1logs.copy()

classified_logs['question_class'] = classified_logs['question'].apply(classify_question)

# %%
classified_logs
# Out:
#       user                                           question  \
# 0      100                                                 hi
# 1      100                                             Simone
# 2      100                                        I am Simone
# 3      100                           what is software testing
# 4      100                         what is structural testing
# ...    ...                                                ...
# 2984    98  what is the definition of state transition tes...
# 2985    98                              what is graph testing
# 2986    98                       what is graph matrix testing
# 2987    99                                                 Hi
# 2988    99         Talk to me about software testing activity
#
#                                                  answer       class
# 0                                   Hello, how are you?       Greet
# 1     Sorry, I still can't answer that.. Could you a...   Statement
# 2     Sorry, I still can't answer that.. Could you a...   Statement
# 3     Software testing is an activity of software en...  whQuestion
# 4     Structural testing (or White-Box testing) is a...  whQuestion
# ...                                                 ...         ...
# 2984  It is a criteria within functional testing, bu...  whQuestion
# 2985  Software testing is an activity of software en...  whQuestion
# 2986  It is a criteria within functional testing, bu...  whQuestion
# 2987                          Hello, ask me a question!       Greet
# 2988  Sorry, I still can't answer that.. Could you a...   Statement
#
# [2989 rows x 4 columns]

# %%
classified_logs['question_class'].unique()
# Out:
# array(['Greet', 'Statement', 'whQuestion', 'Clarify', 'nAnswer', 'Bye',
#        'ynQuestion', 'Emphasis', 'yAnswer', 'Reject', 'System', 'Emotion',
#        'Continuer', 'Other', 'Accept'], dtype=object)

# %%
questions = classified_logs[classified_logs['question_class'] == 'whQuestion']

questions
# Out:
#       user                                           question  \
# 3      100                           what is software testing
# 4      100                         what is structural testing
# 5      100                       what is a software technique
# 6      100                             what is system testing
# 7      100                               what is unit testing
# ...    ...                                                ...
# 2982    98                           what is state transition
# 2983    98                   what is state transition testing
# 2984    98  what is the definition of state transition tes...
# 2985    98                              what is graph testing
# 2986    98                       what is graph matrix testing
#
#                                                  answer question_class
# 3     Software testing is an activity of software en...     whQuestion
# 4     Structural testing (or White-Box testing) is a...     whQuestion
# 5     Sorry, I still can't answer that.. Could you a...     whQuestion
# 6     System testing is a level of software testing ...     whQuestion
# 7     Unit testing verifies the functioning in isola...     whQuestion
# ...                                                 ...            ...
# 2982  It is a criteria within functional testing, bu...     whQuestion
# 2983  It is a criteria within functional testing, bu...     whQuestion
# 2984  It is a criteria within functional testing, bu...     whQuestion
# 2985  Software testing is an activity of software en...     whQuestion
# 2986  It is a criteria within functional testing, bu...     whQuestion
#
# [1395 rows x 4 columns]

# %%
statements = classified_logs[classified_logs['question_class'] == 'Statement']

# %%
classified_logs[classified_logs['question_class'] == 'yAnswer']
# Out:
#       user                                           question  \
# 99     105                                                yes
# 206    110                                                Yes
# 550    130                                                Yes
# 695    143                      Wkato is stranger information
# 1110   154       ou can give the example of information error
# 1122   154  What is the difference between failure, error,...
# 1202    15                                                Yes
# 1301   164                                I am feeling afraid
# 1544    18                                                yes
# 1724   215                                                yes
# 1737   218                                                yes
# 1890    25                                                yes
# 1944    26                                       yes, 6608332
# 1978    28                                                yes
# 1990    28                                                yes
# 2115    39                                                Yes
# 2201    49                                                Yes
# 2263    52                                                yes
# 2621    83                                                Yes
# 2978    98                                                Yes
#
#                                                  answer question_class
# 99    Sorry, I still can't answer that.. Could you a...        yAnswer
# 206   Sorry, I still can't answer that.. Could you a...        yAnswer
# 550   Sorry, I still can't answer that.. Could you a...        yAnswer
# 695   Sorry, I still can't answer that.. Could you a...        yAnswer
# 1110  An example of an error could be the access of ...        yAnswer
# 1122  A software defect or bug is a condition in a s...        yAnswer
# 1202                                        I hear you.        yAnswer
# 1301  Sorry, I still can't answer that.. Could you a...        yAnswer
# 1544                                      Tell me more.        yAnswer
# 1724  Sorry, I still can't answer that.. Could you a...        yAnswer
# 1737  Sorry, I still can't answer that.. Could you a...        yAnswer
# 1890                                                Ah.        yAnswer
# 1944                     That's interesting.. Hi there!        yAnswer
# 1978                                                OK.        yAnswer
# 1990                             How do you know it is?        yAnswer
# 2115                         I'm not here to be tested.        yAnswer
# 2201                         I'm not here to be tested.        yAnswer
# 2263                       What would you like to know?        yAnswer
# 2621                   I don't know how to respond this        yAnswer
# 2978  Sorry, I still can't answer that.. Could you a...        yAnswer

# %%
classified_logs.to_csv('tb_v1_dataset_classified.csv')
