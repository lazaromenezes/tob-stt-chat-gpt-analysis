# %%
import pandas as pd

tob_data = pd.read_csv('./similarity_sample_dataset_changed.csv', index_col='index')

similarity_values = ['v1_v2', 'v1_gpt', 'v2_gpt']

v1_and_v2_answered = 'could_v1_answer == 1 and could_v2_answer == 1'

# %%
tob_data[similarity_values].plot.box()
# Out:
# <Axes: >

# %%
tob_data.query(v1_and_v2_answered)[similarity_values].plot.box()
# Out:
# <Axes: >

# %%
tob_data[similarity_values].hist()
# Out:
# array([[<Axes: title={'center': 'v1_v2'}>,
#         <Axes: title={'center': 'v1_gpt'}>],
#        [<Axes: title={'center': 'v2_gpt'}>, <Axes: >]], dtype=object)

# %%
tob_data.query(v1_and_v2_answered)[similarity_values].hist()
# Out:
# array([[<Axes: title={'center': 'v1_v2'}>,
#         <Axes: title={'center': 'v1_gpt'}>],
#        [<Axes: title={'center': 'v2_gpt'}>, <Axes: >]], dtype=object)
