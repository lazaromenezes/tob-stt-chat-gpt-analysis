# %%
import pandas as pd
from top2vec import Top2Vec

data = pd.read_csv("./tob_v1_dataset")
# Out:
# /opt/conda/lib/python3.11/site-packages/umap/distances.py:1063: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /opt/conda/lib/python3.11/site-packages/umap/distances.py:1071: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# ...

# %%
data
# Out:
#       user                                           question  \
# 0      100                                                 hi
# 1      100                                             Simone
# 2      100                                        I am Simone
# 3      100                           what is software testing
# 4      100                         what is structural testing
# ...    ...                                                ...
# 2984    98  what is the definition of state transition tes...
# 2985    98                              what is graph testing
# 2986    98                       what is graph matrix testing
# 2987    99                                                 Hi
# 2988    99         Talk to me about software testing activity
#
#                                                  answer
# 0                                   Hello, how are you?
# 1     Sorry, I still can't answer that.. Could you a...
# ...

# %%
model = Top2Vec(documents=data['question'].values, speed="deep-learn", workers=8)
# Out:
# 2023-09-12 14:01:18,192 - top2vec - INFO - Pre-processing documents for training
# 2023-09-12 14:01:18,525 - top2vec - INFO - Creating joint document/word embedding
# 2023-09-12 14:01:37,877 - top2vec - INFO - Creating lower dimension embedding of documents
# 2023-09-12 14:02:25,208 - top2vec - INFO - Finding dense areas of documents
# 2023-09-12 14:02:25,584 - top2vec - INFO - Finding topics

# %%
model.get_num_topics()
# Out:
# 10

# %%
model.get_topics()
# Out:
# (array([['equivalence', 'me', 'example', 'functional', 'analysis',
#          'hello', 'criteria', 'iniciar', 'fault', 'between', 'class',
#          'conversa', 'an', 'testing', 'failure', 'the', 'you', 'what',
#          'to', 'know', 'are', 'can', 'hi', 'case', 'box', 'how',
#          'software', 'partitioning', 'and', 'test', 'error', 'of',
#          'value', 'do', 'is', 'unit', 'give', 'tob_stt', 'difference'],
#         ['unit', 'partitioning', 'equivalence', 'analysis', 'you',
#          'difference', 'error', 'between', 'is', 'iniciar', 'functional',
#          'and', 'hello', 'conversa', 'hi', 'to', 'how', 'of', 'give',
#          'class', 'case', 'can', 'me', 'test', 'what', 'box', 'fault',
#          'value', 'software', 'example', 'testing', 'tob_stt', 'know',
#          'criteria', 'the', 'do', 'an', 'are', 'failure'],
#         ['case', 'can', 'you', 'criteria', 'to', 'unit', 'me', 'fault',
#          'test', 'functional', 'partitioning', 'failure', 'are', 'value',
# ...

# %%
model2 = Top2Vec(documents=data['question'].values, speed="deep-learn", workers=8)
# Out:
# 2023-09-12 14:06:21,310 - top2vec - INFO - Pre-processing documents for training
# 2023-09-12 14:06:21,347 - top2vec - INFO - Creating joint document/word embedding
# 2023-09-12 14:07:49,995 - top2vec - INFO - Creating lower dimension embedding of documents
# 2023-09-12 14:08:13,776 - top2vec - INFO - Finding dense areas of documents
# 2023-09-12 14:08:13,928 - top2vec - INFO - Finding topics

# %%
model2.get_num_topics()
# Out:
# 10
